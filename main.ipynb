# %%
from data_fetching import MyCorr

mycorr = MyCorr('')

# %%
version = 0 
table_id = 'tab'
engine = 'pandas'

# %%
df =  mycorr.get_dataframe(table_id, version, engine)
display(df)

# %%
display(df.describe())
display(test_pd.describe())

# %%
diff = df.compare(test_pd)
print(diff)

# %%
print("Data types in df:")
print(df.dtypes)

print("\nData types in test_pd:")
print(test_pd.dtypes)
